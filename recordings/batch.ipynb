# %%
from logger import logger

# %%
# %run "1 - generate stats.ipynb"
logger.info('*** finished ***')
# Out:
# 2024-01-09 14:18:14 - INFO  - <module> - retrieved 423 files
#  |██████████████████████████████████████████████████| 100.0%
# 2024-01-09 14:18:44 - INFO  - <module> - *** finished ***

# %%
# %run "2 - analyse stats.ipynb"
logger.info('*** finished ***')
# Out:
# 2024-01-09 14:18:46 - INFO  - <module> - *** finished ***
