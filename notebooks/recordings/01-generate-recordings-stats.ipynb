# %% [markdown]
# # Generate Stats
# Processes a set of audio files and produces a dataframe and a dataset with the stats

# %% [markdown]
# ## Imports

# %%
# %%capture --no-stderr
# %reload_ext autoreload
# %autoreload 2

# %%
# Suppress Python warnings
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
from datetime import timedelta, datetime

import os
import re
from glob import glob

# local import
from henryk_analysis.logger import *
from henryk_analysis.config import *
from henryk_analysis.recordings import recordings
# Out:
# 2026-03-06 18:34:26.267 | INFO     | henryk_analysis.config:<module>:92 - PROJ_ROOT path is: /home/lab/workspace/private/henryk/henryk-analysis

# %% [markdown]
# ## Parameters

# %%
# params
logger.info(f"using parquet file: {FILE_RECORDINGS_STATS_PARQUET}")
logger.info(f"using audio files path: {DIR_RECORDINGS}")
# Out:
# 2026-03-06 18:34:26.403 | INFO     | __main__:<module>:2 - using parquet file: /home/lab/workspace/private/henryk/henryk-analysis/data/processed/henryk_recordings_stats.parquet
# 2026-03-06 18:34:26.403 | INFO     | __main__:<module>:3 - using audio files path: /mnt/onedrive/My Private/My documents/Other/Henryk/Alienacja rodzicielska materiały/Wiadomości do Henryczka

# %% [markdown]
# ## Process Files

# %%
# load paths to all audio files from wiadomości do Henryczka
df = recordings.get_recordings_info(path_recordings=DIR_RECORDINGS)
# Out:
# Output()
# 2026-03-06 18:34:28.292 | INFO     | henryk_analysis.recordings.recordings:get_recordings_info:62 - retrieved 873 files
# 2026-03-06 18:35:26.124 | WARNING  | henryk_analysis.recordings.recordings:get_audio_file_info:137 -
# encountered error for /mnt/onedrive/My Private/My documents/Other/Henryk/Alienacja rodzicielska
# materiały/Wiadomości do Henryczka/filmy/Henryk 2023-06-01 Wujek Mikołaj życzenia na dzień dziecka.mp4: truncated
# data
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 2026-03-06 18:35:26.327 | INFO     | henryk_analysis.recordings.recordings:get_recordings_info:94 - generated stats for 872 audio recordings

# %% [markdown]
# ## Write data to file

# %%
# save to csv
df.sort_values('date', inplace=True)
df.to_parquet(FILE_RECORDINGS_STATS_PARQUET, index=False)

# %% [markdown]
# # References
# - https://www.kaggle.com/code/robikscube/working-with-audio-in-python
# - https://towardsdatascience.com/get-to-know-audio-feature-extraction-in-python-a499fdaefe42
# - https://stackoverflow.com/questions/55669182/how-to-fix-filenotfounderror-winerror-2-the-system-cannot-find-the-file-speci
