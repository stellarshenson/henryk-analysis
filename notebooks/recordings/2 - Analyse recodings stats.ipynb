# %% [markdown]
# # Analyse Recordings Stats

# %% [markdown]
# ## Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
# Suppress Python warnings
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

# local imports
from lib_henryk.logger import *
from lib_henryk.config import *
from lib_henryk.recordings import recordings

# %%
# load data
df = pd.read_parquet(FILE_RECORDINGS_STATS_PARQUET)

# convert date
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')

# %% [markdown]
# ## Generate Plots

# %%
recordings.plot_recordings_stats(df)

# %% [markdown]
# ## Run Gaps Analysis

# %%
recordings.analyze_and_print_gaps(df)
# Out:
# Analyzing temporal data for discontinuities, Star Captain...
# Located 15 temporal discontinuities exceeding 1 days:
# ============================================================
# Gap 1:
#   Start: 2022-06-10 00:00:00
#   End:   2022-06-13 00:00:00
#   Duration: 2.00 days
# ------------------------------------------------------------
# Gap 2:
#   Start: 2022-07-08 00:00:00
#   End:   2022-07-11 00:00:00
#   Duration: 2.00 days
# ------------------------------------------------------------
# Gap 3:
#   Start: 2022-07-22 00:00:00
#   End:   2022-07-25 00:00:00
#   Duration: 2.00 days
# ------------------------------------------------------------
# Gap 4:
#   Start: 2022-08-06 00:00:00
#   End:   2022-08-10 00:00:00
#   Duration: 3.00 days
# ------------------------------------------------------------
# Gap 5:
#   Start: 2022-08-26 00:00:00
#   End:   2022-08-29 00:00:00
#   Duration: 2.00 days
# ------------------------------------------------------------
# Gap 6:
#   Start: 2022-08-30 00:00:00
#   End:   2022-09-02 00:00:00
#   Duration: 2.00 days
# ------------------------------------------------------------
# Gap 7:
#   Start: 2022-10-16 00:00:00
#   End:   2022-10-19 00:00:00
#   Duration: 2.00 days
# ------------------------------------------------------------
# Gap 8:
#   Start: 2022-10-22 00:00:00
#   End:   2022-10-25 00:00:00
#   Duration: 2.00 days
# ------------------------------------------------------------
# Gap 9:
#   Start: 2022-10-29 00:00:00
#   End:   2022-11-01 00:00:00
#   Duration: 2.00 days
# ------------------------------------------------------------
# Gap 10:
#   Start: 2022-11-09 00:00:00
#   End:   2022-11-12 00:00:00
#   Duration: 2.00 days
# ------------------------------------------------------------
# Gap 11:
#   Start: 2022-12-17 00:00:00
#   End:   2022-12-20 00:00:00
#   Duration: 2.00 days
# ------------------------------------------------------------
# Gap 12:
#   Start: 2023-01-14 00:00:00
#   End:   2023-01-17 00:00:00
#   Duration: 2.00 days
# ------------------------------------------------------------
# Gap 13:
#   Start: 2023-02-08 00:00:00
#   End:   2023-02-11 00:00:00
#   Duration: 2.00 days
# ------------------------------------------------------------
# Gap 14:
#   Start: 2023-06-22 00:00:00
#   End:   2023-06-25 00:00:00
#   Duration: 2.00 days
# ------------------------------------------------------------
# Gap 15:
#   Start: 2024-05-17 00:00:00
#   End:   2024-05-20 00:00:00
#   Duration: 2.00 days
